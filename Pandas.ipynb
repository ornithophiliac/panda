# %%
import pandas as pd

# %%
# how to read a file in pandas

# %%
df = pd.read_csv('services.csv')

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head() # shows first five records
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df.tail() # displays last 5 records
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
type(df) # data frame is the tabular form displayed as above
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df['service_areas']
# Out:
# 0                                     Colma
# 1                          San Mateo County
# 2                          San Mateo County
# 3                          San Mateo County
# 4                          San Mateo County
# 5                          San Mateo County
# 6       Belmont, Burlingame, East Palo Alto
# 7                   Belmont, East Palo Alto
# 8                          San Mateo County
# 9                          San Mateo County
# 10                         San Mateo County
# 11                                Daly City
# 12                         San Mateo County
# 13      Belmont, Burlingame, East Palo Alto
# 14         Alameda County, San Mateo County
# 15                                      NaN
# 16    Colma, Daly City, South San Francisco
# 17                           East Palo Alto
# 18                      Belmont, Burlingame
# 19                                      NaN
# 20                         San Mateo County
# ...

# %%
type(df['service_areas']) # series is equivalent to list in pandas
# Out:
# pandas.core.series.Series

# %%
list(df['service_areas'])
# Out:
# ['Colma',
#  'San Mateo County',
#  'San Mateo County',
#  'San Mateo County',
#  'San Mateo County',
#  'San Mateo County',
#  'Belmont, Burlingame, East Palo Alto',
#  'Belmont, East Palo Alto',
#  'San Mateo County',
#  'San Mateo County',
#  'San Mateo County',
#  'Daly City',
#  'San Mateo County',
#  'Belmont, Burlingame, East Palo Alto',
#  'Alameda County, San Mateo County',
#  nan,
#  'Colma, Daly City, South San Francisco',
#  'East Palo Alto',
#  'Belmont, Burlingame',
#  nan,
#  'San Mateo County',
#  'Alameda County, San Mateo County',
#  'San Mateo County, Alameda County']

# %%
df[['service_areas']]
# Out:
#                             service_areas
# 0                                   Colma
# 1                        San Mateo County
# 2                        San Mateo County
# 3                        San Mateo County
# 4                        San Mateo County
# 5                        San Mateo County
# 6     Belmont, Burlingame, East Palo Alto
# 7                 Belmont, East Palo Alto
# 8                        San Mateo County
# 9                        San Mateo County
# 10                       San Mateo County
# 11                              Daly City
# 12                       San Mateo County
# 13    Belmont, Burlingame, East Palo Alto
# 14       Alameda County, San Mateo County
# 15                                    NaN
# 16  Colma, Daly City, South San Francisco
# 17                         East Palo Alto
# 18                    Belmont, Burlingame
# 19                                    NaN
# 20                       San Mateo County
# ...

# %%
type(df[['service_areas']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['email', 'keywords']]
# Out:
#                     email                                           keywords
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3                     NaN  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4                     NaN     COMMUNITY SERVICES, Speakers, Automobile Loans
# 5                     NaN  ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6                     NaN  ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 9                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 10                    NaN  EDUCATION SERVICES, Library, Libraries, Public...
# ...

# %%
df.dtypes # column wise data types will be displayed
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
pd.read_excel('LUSID Excel - Setting up your market data.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html ")

# %%
pip install lxml

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3=url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.to_csv("players_data.csv",index=False)

# %%
# pandas advance

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[["Name","Sex","Cabin"]]
# Out:
#                                                   Name     Sex Cabin
# 0                              Braund, Mr. Owen Harris    male   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                               Heikkinen, Miss. Laina  female   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123
# 4                             Allen, Mr. William Henry    male   NaN
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male   NaN
# 887                       Graham, Miss. Margaret Edith  female   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  C148
# 890                                Dooley, Mr. Patrick    male   NaN
#
# [891 rows x 3 columns]

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
 df[df.dtypes[df.dtypes == "int64"].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
df[['Ticket']][4:11]
# Out:
#      Ticket
# 4    373450
# 5    330877
# 6     17463
# 7    349909
# 8    347742
# 9    237736
# 10  PP 9549

# %%
df["new_col"]=0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['new_col']= df['PassengerId'] + df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        4
# 1      0          PC 17599  71.2833   C85        C        3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        6
# 3      0            113803  53.1000  C123        S        5
# ...

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        4
# 1      0          PC 17599  71.2833   C85        C        3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        6
# 3      0            113803  53.1000  C123        S        5
# ...

# %%
df[df['Age']>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Age']>18])
# Out:
# 575

# %%
df['Fare']>32
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']>32]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Fare']>32])
# Out:
# 211

# %%
df[df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
len(df[df['Fare']==0])
# Out:
# 15

# %%
df['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col
# ...

# %%
df[df['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex']=='female') & (df['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex']=='male') & (df['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      new_col
# 258      260
# 679      681
# 737      739

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        4
# 1      0          PC 17599  71.2833   C85        C        3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        6
# 3      0            113803  53.1000  C123        S        5
# ...

# %%
df[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col
# 0      0  A/5 21171   7.2500   NaN        S        4
# 1      0   PC 17599  71.2833   C85        C        3

# %%
df[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['PassengerId', 'Survived', 'Pclass']][0:2]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col
# 0      0  A/5 21171   7.2500   NaN        S        4
# 1      0   PC 17599  71.2833   C85        C        3

# %%
df.iloc[0:2,['PassengerId', 'Survived', 'Pclass']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.iloc[0:2,['PassengerId', 'Survived', 'Pclass']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[0:2,['PassengerId', 'Survived', 'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
df.iloc[0:2,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col'],
#       dtype='object')

# %%
s=df['Name'][0:10]

# %%
len(s)
# Out:
# 891

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
l=['a','b','c','d','e','f','g','h','i','j']

# %%
s1=pd.Series(list(s),index=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s1=pd.Series(list(s),index=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:425, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     422 name = ibase.maybe_extract_name(name, data, type(self))
#     424 if index is not None:
# --> 425     index = ensure_index(index)
#     427 if dtype is not None:
#     428     dtype = self._validate_dtype(dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7128, in ensure_index(index_like, copy)
#    7126         return Index(index_like, copy=copy, tupleize_cols=False)
#    7127 else:
# -> 7128     return Index(index_like, copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:516, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
# ...

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d={'key1':[3,4,5,6],
   'key2': [4,5,6,7],
   'key3' : [1,2,3,4]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     4     1
# 1     4     5     2
# 2     5     6     3
# 3     6     7     4

# %%
df1=pd.read_csv('taxonomy.csv.xls')

# %%
pd.read_csv('players_data.csv')
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
g=df.groupby('Survived')

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
g.sum()
# Out:
#                                                        Name  Pclass  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...    1390
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...     666
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalemale...   8184.67    161
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282347742237736PP 9549113...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16498.1294  C85G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D1...
#
# ...

# %%
g.mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
g1= df.groupby('Pclass')

# %%
g1

# %%
g1.sum()
# Out:
#                                                      Name  Survived  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...       135
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...        87
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...       119
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalemalefemalemalemalemalefemalemalemalefema...  7076.42     89
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991746311378311378819950PC 17601PC 17569...  18124.3125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# 3         193  A/5 21171STON/O2. 3101282373450330877349909347...   6714.6951
#
# ...

# %%
g1.mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
g1.max()['Fare'].T
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
g1

# %%
g1.max().T()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df(['Name' ,'Survived'	,'Pclass'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df(['Name' ,'Survived'	,'Pclass'])
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df[['Name','Survived','Pclass']][0:5]

# %%
df1
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df2=df[['Name','Survived','Pclass']][5:10]

# %%
df2
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
df3=pd.concat([df1,df2],axis=1)

# %%
df3.fillna('Mukul')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 4                           Allen, Mr. William Henry      0.0    3.0
# 5                                              Mukul    Mukul  Mukul
# 6                                              Mukul    Mukul  Mukul
# 7                                              Mukul    Mukul  Mukul
# 8                                              Mukul    Mukul  Mukul
# 9                                              Mukul    Mukul  Mukul
#
#                                                 Name Survived Pclass
# 0                                              Mukul    Mukul  Mukul
# 1                                              Mukul    Mukul  Mukul
# ...

# %%
data1=pd.DataFrame({'key1':[1,2,3,4,5],'key2':[4,5,6,7,8],'key3':[3,4,5,65,56]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7    65
# 4     5     8    56

# %%
data2=pd.DataFrame({'key1':[1,3,5,7,9],'key5':[3,5,7,9,1],'key6':[2,3,5,7,11]})

# %%
data2
# Out:
#    key1  key5  key6
# 0     1     3     2
# 1     3     5     3
# 2     5     7     5
# 3     7     9     7
# 4     9     1    11

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key5  key6
# 0     1     4     3     3     2
# 1     3     6     5     5     3
# 2     5     8    56     7     5

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key5  key6
# 0     1     4     3   3.0   2.0
# 1     2     5     4   NaN   NaN
# 2     3     6     5   5.0   3.0
# 3     4     7    65   NaN   NaN
# 4     5     8    56   7.0   5.0

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key5  key6
# 0     1   4.0   3.0     3     2
# 1     3   6.0   5.0     5     3
# 2     5   8.0  56.0     7     5
# 3     7   NaN   NaN     9     7
# 4     9   NaN   NaN     1    11

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key5  key6
# 0        1     4     3       1     3     2
# 1        1     4     3       3     5     3
# 2        1     4     3       5     7     5
# 3        1     4     3       7     9     7
# 4        1     4     3       9     1    11
# 5        2     5     4       1     3     2
# 6        2     5     4       3     5     3
# 7        2     5     4       5     7     5
# 8        2     5     4       7     9     7
# 9        2     5     4       9     1    11
# 10       3     6     5       1     3     2
# 11       3     6     5       3     5     3
# 12       3     6     5       5     7     5
# 13       3     6     5       7     9     7
# 14       3     6     5       9     1    11
# 15       4     7    65       1     3     2
# 16       4     7    65       3     5     3
# 17       4     7    65       5     7     5
# 18       4     7    65       7     9     7
# 19       4     7    65       9     1    11
# 20       5     8    56       1     3     2
# ...

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key5  key6
# 0     1   4.0   3.0   3.0   2.0
# 1     2   5.0   4.0   NaN   NaN
# 2     3   6.0   5.0   5.0   3.0
# 3     4   7.0  65.0   NaN   NaN
# 4     5   8.0  56.0   7.0   5.0
# 5     7   NaN   NaN   9.0   7.0
# 6     9   NaN   NaN   1.0  11.0

# %%
data1 = pd.DataFrame({'key1': [1,2,3,4,5], 'key2' : [1,3,5,7,9], 'key3': [2,4,6,8,10]},index=['a','b','c','d','e'])

# %%
data2 = pd.DataFrame({'key11': [1,2,3,4,5], 'key12' : [1,3,5,7,9], 'key13': [2,4,6,8,10]},index=['a','b','h','i','j'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     1     2
# b     2     3     4
# c     3     5     6
# d     4     7     8
# e     5     9    10

# %%
data2
# Out:
#    key11  key12  key13
# a      1      1      2
# b      2      3      4
# h      3      5      6
# i      4      7      8
# j      5      9     10

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key12  key13
# a   1.0   1.0   2.0      1      1      2
# b   2.0   3.0   4.0      2      3      4
# h   NaN   NaN   NaN      3      5      6
# i   NaN   NaN   NaN      4      7      8
# j   NaN   NaN   NaN      5      9     10

# %%
data1.join(data2,how='left')
# Out:
#    key1  key2  key3  key11  key12  key13
# a     1     1     2    1.0    1.0    2.0
# b     2     3     4    2.0    3.0    4.0
# c     3     5     6    NaN    NaN    NaN
# d     4     7     8    NaN    NaN    NaN
# e     5     9    10    NaN    NaN    NaN

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key12  key13
# a   1.0   1.0   2.0    1.0    1.0    2.0
# b   2.0   3.0   4.0    2.0    3.0    4.0
# c   3.0   5.0   6.0    NaN    NaN    NaN
# d   4.0   7.0   8.0    NaN    NaN    NaN
# e   5.0   9.0  10.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    3.0    5.0    6.0
# i   NaN   NaN   NaN    4.0    7.0    8.0
# j   NaN   NaN   NaN    5.0    9.0   10.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key12  key13
# 0      1     1     2      1      1      2
# 1      1     1     2      2      3      4
# 2      1     1     2      3      5      6
# 3      1     1     2      4      7      8
# 4      1     1     2      5      9     10
# 5      2     3     4      1      1      2
# 6      2     3     4      2      3      4
# 7      2     3     4      3      5      6
# 8      2     3     4      4      7      8
# 9      2     3     4      5      9     10
# 10     3     5     6      1      1      2
# 11     3     5     6      2      3      4
# 12     3     5     6      3      5      6
# 13     3     5     6      4      7      8
# 14     3     5     6      5      9     10
# 15     4     7     8      1      1      2
# 16     4     7     8      2      3      4
# 17     4     7     8      3      5      6
# 18     4     7     8      4      7      8
# 19     4     7     8      5      9     10
# 20     5     9    10      1      1      2
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare_INR']= df['Fare'].apply(lambda x :x*80)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_INR
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0            113803  53.1000  C123        S  4248.000
# ...

# %%
df['Fare_INR']= df['Fare'].apply(lambda x :x*80)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['name_len']= df['Name'].apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_INR  name_len
# 0      0         A/5 21171   7.2500   NaN        S   580.000        23
# 1      0          PC 17599  71.2833   C85        C  5702.664        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000        22
# ...

# %%
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>10:
        return "high"

# %%
df['cat_fare']= df['Fare'].apply(cat_fare)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_INR  name_len  \
# 0      0         A/5 21171   7.2500   NaN        S   580.000        23
# 1      0          PC 17599  71.2833   C85        C  5702.664        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000        22
# ...

# %%
import pandas as pd

# %%
data = {"a" :[1,2,3,4],
        "b" : [4,5,6,7],
       "c": ["sudh","mukul","tanaji","kendre"]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   mukul
# 2  3  6  tanaji
# 3  4  7  kendre

# %%
df.set_index('a')
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   mukul
# 3  6  tanaji
# 4  7  kendre

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   mukul
# 2  3  6  tanaji
# 3  4  7  kendre

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   mukul
# 3  6  tanaji
# 4  7  kendre

# %%
df.reset_index()
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   mukul
# 2  3  6  tanaji
# 3  4  7  kendre

# %%
df
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   mukul
# 3  6  tanaji
# 4  7  kendre

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   mukul
# 2  3  6  tanaji
# 3  4  7  kendre

# %%
data = {"a" :[1,2,3,4],
        "b" : [4,5,6,7],
       "c": ["sudh","mukul","tanaji","kendre"]}
df1=pd.DataFrame(data,index=['a', 'b', 'c', 'd'])

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
df1.reindex(['b','c','d','a'])
# Out:
#    a  b       c
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre
# a  1  4    sudh

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000002BF88C9F9A0>

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, a       1
# b       4
# c    sudh
# Name: 0, dtype: object)
# (1, a        2
# b        5
# c    mukul
# Name: 1, dtype: object)
# (2, a         3
# b         6
# c    tanaji
# Name: 2, dtype: object)
# (3, a         4
# b         7
# c    kendre
# Name: 3, dtype: object)

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
for i,j in df1.iterrows():
    print(i,j)
# Out:
# a a       1
# b       4
# c    sudh
# Name: a, dtype: object
# b a        2
# b        5
# c    mukul
# Name: b, dtype: object
# c a         3
# b         6
# c    tanaji
# Name: c, dtype: object
# d a         4
# b         7
# c    kendre
# Name: d, dtype: object

# %%
for col_name,column in df1.iterrows():
    print(col_name,column)
# Out:
# a a       1
# b       4
# c    sudh
# Name: a, dtype: object
# b a        2
# b        5
# c    mukul
# Name: b, dtype: object
# c a         3
# b         6
# c    tanaji
# Name: c, dtype: object
# d a         4
# b         7
# c    kendre
# Name: d, dtype: object

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
def test(x):
    return x.sum()
df1.apply(test)
# Out:
# a                       10
# b                       22
# c    sudhmukultanajikendre
# dtype: object

# %%
def test(x):
    return x.sum()
df1.apply(test,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 def test(x):
#       2     return x.sum()
# ----> 3 df1.apply(test,axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# ...

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
df2=df1[['a','b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x : x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   mukul
# c  3  6  tanaji
# d  4  7  kendre

# %%
df.sort_values('c')
# Out:
#    a  b       c
# 3  4  7  kendre
# 1  2  5   mukul
# 0  1  4    sudh
# 2  3  6  tanaji

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   mukul
# 2  3  6  tanaji
# 3  4  7  kendre

# %%
df.sort_index(ascending=False)
# Out:
#    a  b       c
# 3  4  7  kendre
# 2  3  6  tanaji
# 1  2  5   mukul
# 0  1  4    sudh

# %%
df3 =pd.DataFrame({"Desc" :["mukul kendre tanaji pandurang raghio malhari surekha krishna dahiwalikar darshana baban prashant prabha pinky yash "]})

# %%
df3
# Out:
#                                                                                                                   Desc
# 0  mukul kendre tanaji pandurang raghio malhari surekha krishna dahiwalikar darshana baban prashant prabha pinky yash

# %%
pd.set_option("display.max_colwidth",1000)

# %%
df3
# Out:
#                                                                                                                   Desc
# 0  mukul kendre tanaji pandurang raghio malhari surekha krishna dahiwalikar darshana baban prashant prabha pinky yash

# %%
df3['len'] = df3['Desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                   Desc  \
# 0  mukul kendre tanaji pandurang raghio malhari surekha krishna dahiwalikar darshana baban prashant prabha pinky yash
#
#    len
# 0  115

# %%
df3['word_count']= df3['Desc'].apply(lambda x : len(x.split()))

# %%
df3
# Out:
#                                                                                                                   Desc  \
# 0  mukul kendre tanaji pandurang raghio malhari surekha krishna dahiwalikar darshana baban prashant prabha pinky yash
#
#    len  word_count
# 0  115          15

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   mukul
# 2  3  6  tanaji
# 3  4  7  kendre

# %%
df['a'].mean()
# Out:
# 2.5

# %%
df['a'].sum()
# Out:
# 10

# %%
df['a'].median()
# Out:
# 2.5

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()
# Out:
# 1.2909944487358056

# %%
df['a'].max()
# Out:
# 4

# %%
df['a'].min()
# Out:
# 1

# %%
df4=pd.DataFrame({'a':[3,4,5,6,7,8,9,1,2,3,4,78]})

# %%
df4
# Out:
#      a
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# 6    9
# 7    1
# 8    2
# 9    3
# 10   4
# 11  78

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0      NaN
# 1      3.5
# 2      4.5
# 3      5.5
# 4      6.5
# 5      7.5
# 6      8.5
# 7      5.0
# 8      1.5
# 9      2.5
# 10     3.5
# 11    41.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0      3.0
# 1      4.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      8.0
# 6      9.0
# 7      1.0
# 8      2.0
# 9      3.0
# 10     4.0
# 11    78.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).mean()
# Out:
# 0           NaN
# 1           NaN
# 2      4.000000
# 3      5.000000
# 4      6.000000
# 5      7.000000
# 6      8.000000
# 7      6.000000
# 8      4.000000
# 9      2.000000
# 10     3.000000
# 11    28.333333
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).sum()
# Out:
# 0      NaN
# 1      7.0
# 2      9.0
# 3     11.0
# 4     13.0
# 5     15.0
# 6     17.0
# 7     10.0
# 8      3.0
# 9      5.0
# 10     7.0
# 11    82.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).min()
# Out:
# 0     NaN
# 1     3.0
# 2     4.0
# 3     5.0
# 4     6.0
# 5     7.0
# 6     8.0
# 7     1.0
# 8     1.0
# 9     2.0
# 10    3.0
# 11    4.0
# Name: a, dtype: float64

# %%
df4['a'].cumsum()
# Out:
# 0       3
# 1       7
# 2      12
# 3      18
# 4      25
# 5      33
# 6      42
# 7      43
# 8      45
# 9      48
# 10     52
# 11    130
# Name: a, dtype: int64

# %%
pd.date_range(start='2023-01-30', end = '2023-05-30')
# Out:
# DatetimeIndex(['2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02',
#                '2023-02-03', '2023-02-04', '2023-02-05', '2023-02-06',
#                '2023-02-07', '2023-02-08',
#                ...
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30'],
#               dtype='datetime64[ns]', length=121, freq='D')

# %%
df5 = pd.DataFrame({'date' : ['2023-01-30', '2023-01-31', '2023-02-01']})

# %%
df5
# Out:
#          date
# 0  2023-01-30
# 1  2023-01-31
# 2  2023-02-01

# %%
df5['updated_date']=pd.to_datetime(df5['date'])

# %%
df5
# Out:
#          date updated_date
# 0  2023-01-30   2023-01-30
# 1  2023-01-31   2023-01-31
# 2  2023-02-01   2023-02-01

# %%
df5['year']=df5['updated_date'].dt.year

# %%
df5
# Out:
#          date updated_date  year
# 0  2023-01-30   2023-01-30  2023
# 1  2023-01-31   2023-01-31  2023
# 2  2023-02-01   2023-02-01  2023

# %%
df5['month']=df5['updated_date'].dt.month

# %%
df5
# Out:
#          date updated_date  year  month
# 0  2023-01-30   2023-01-30  2023      1
# 1  2023-01-31   2023-01-31  2023      1
# 2  2023-02-01   2023-02-01  2023      2

# %%
df5['day']=df5['updated_date'].dt.day

# %%
df5
# Out:
#          date updated_date  year  month  day
# 0  2023-01-30   2023-01-30  2023      1   30
# 1  2023-01-31   2023-01-31  2023      1   31
# 2  2023-02-01   2023-02-01  2023      2    1

# %%
import pandas as pd

# %%
pd.Timedelta(days=1, hours = 5, minutes = 45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt = pd.to_datetime('2022-06-09')

# %%
td = pd.Timedelta(days=1)

# %%
dt+td
# Out:
# Timestamp('2022-06-10 00:00:00')

# %%
data = ["sudh" , "krish", "hitesh", "navin"]

# %%
cat =pd.Categorical(data)

# %%
cat
# Out:
# ['sudh', 'krish', 'hitesh', 'navin']
# Categories (4, object): ['hitesh', 'krish', 'navin', 'sudh']

# %%
cat.value_counts()
# Out:
# hitesh    1
# krish     1
# navin     1
# sudh      1
# Name: count, dtype: int64

# %%
d=pd.Series([1,3,5,7,9,2,4,6,8])
d
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# 5    2
# 6    4
# 7    6
# 8    8
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({"a" : [3,6,9,7,5],
                  "b" : [1,3,2,4,8]})

# %%
df
# Out:
#    a  b
# 0  3  1
# 1  6  3
# 2  9  2
# 3  7  4
# 4  5  8

# %%
df.plot(x='a', y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a', y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
d=pd.Series([1,2,3,4,5,6,4,23,1,3,5,6,7,4,])

# %%
d.plot.pie()
# Out:
# <Axes: >
